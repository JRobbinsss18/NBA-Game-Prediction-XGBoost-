# %%
from nba_api.stats.endpoints import leaguegamefinder, leaguedashplayerstats, commonteamroster, boxscoretraditionalv2
from nba_api.stats.static import teams
import pandas as pd
import time
from sklearn.preprocessing import MinMaxScaler

# %%
team_id = '1610612744'  # Golden State Warriors ID
team_id = int(team_id)
seasons = ["2018-19", "2019-20", "2020-21", "2021-22", "2022-23", "2023-24", "2024-25"] # Seasons to train on

# %%
all_games = []

# %%
for season in seasons:
    print(f"Fetching data for season {season}...")
    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id, season_nullable=season)
    season_games = gamefinder.get_data_frames()[0]
    season_games["SEASON"] = season
    all_games.append(season_games)
    time.sleep(0.5)
# Out:
# Fetching data for season 2018-19...
# Fetching data for season 2019-20...
# Fetching data for season 2020-21...
# Fetching data for season 2021-22...
# Fetching data for season 2022-23...
# Fetching data for season 2023-24...
# Fetching data for season 2024-25...

# %%
df = pd.concat(all_games, ignore_index=True)

# %%
df['WL'] = df['WL'].apply(lambda x: 1 if x == 'W' else 0)

# %%
df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
df = df.sort_values('GAME_DATE').reset_index(drop=True)
df['DaysSinceLast'] = df['GAME_DATE'].diff().dt.days.fillna(0)

# %%
df['IS_HOME_GAME'] = df['MATCHUP'].apply(lambda x: 1 if "vs." in x else 0)

# %%
def get_team_dict():
    team_data = teams.get_teams()
    return {team['id']: team['abbreviation'] for team in team_data}

# %%
def calculate_player_ratings(season):
    df = leaguedashplayerstats.LeagueDashPlayerStats(season=season).get_data_frames()[0]
    metrics = ['PTS', 'REB', 'AST', 'STL', 'BLK', 'PLUS_MINUS', 'NBA_FANTASY_PTS']
    weights = {
        'PTS': 0.4,
        'REB': 0.2,
        'AST': 0.15,
        'STL': 0.1,
        'BLK': 0.1,
        'PLUS_MINUS': 0.05,
        'NBA_FANTASY_PTS': 0.3
    }
    
    total_weight = sum(weights.values())
    weights = {k: v / total_weight for k, v in weights.items()}
    
    scaler = MinMaxScaler()
    df[metrics] = scaler.fit_transform(df[metrics])
    
    df['PLAYER_RATING'] = sum(df[metric] * weight for metric, weight in weights.items())
    
    df['PLAYER_RATING'] = (df['PLAYER_RATING'] * 100).round(2)
    
    df = df.sort_values(by='PLAYER_RATING', ascending=False).reset_index(drop=True)
    return df[['PLAYER_NAME', 'PLAYER_RATING']]

# %%
def generate_player_ratings(seasons):
    player_ratings = {}
    for season in seasons:
        ratings_df = calculate_player_ratings(season)
        player_ratings[season] = ratings_df.set_index('PLAYER_NAME')['PLAYER_RATING'].to_dict()
    return player_ratings

# %%
player_ratings = generate_player_ratings(seasons)

# %%
def find_injured_players(game_id, season, team_abbr):
    team_dict = get_team_dict()

    reverse_team_dict = {abbr: tid for tid, abbr in team_dict.items()}

    if team_abbr not in reverse_team_dict:
        raise ValueError(f"Team abbreviation '{team_abbr}' not found.")

    team_id = reverse_team_dict[team_abbr]

    roster = commonteamroster.CommonTeamRoster(season=season, team_id=team_id)
    roster_data = roster.get_data_frames()[0]
    roster_players = roster_data['PLAYER'].tolist()

    roster_players_normalized = [normalize_name(player) for player in roster_players]

    box_score = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)
    box_score_data = box_score.get_data_frames()[0]

    players_played = box_score_data['PLAYER_NAME'].tolist()
    players_played_normalized = [normalize_name(player) for player in players_played]

    injured_players = [
        roster_players[i]
        for i, player in enumerate(roster_players_normalized)
        if player not in players_played_normalized
    ]

    return injured_players

# %%
def normalize_name(name):
    return name.strip().lower()

# %%
def calculate_injury_score_sequential(df, player_ratings, find_injured_players, team_id):
    team_dict = get_team_dict()
    if team_id not in team_dict:
        raise ValueError(f"Team ID '{team_id}' not found.")
    team_abbr = team_dict[team_id]

    injury_scores = []

    for _, row in df.iterrows():
        game_id = row['GAME_ID']
        season = row['SEASON']

        matchup = row['MATCHUP']
        opponent_abbr = matchup.split()[-1]

        try:
            team_injured = find_injured_players(game_id, season, team_abbr)
            opponent_injured = find_injured_players(game_id, season, opponent_abbr)

            team_injury_rating = sum(player_ratings[season].get(player, 0) for player in team_injured)
            opponent_injury_rating = sum(player_ratings[season].get(player, 0) for player in opponent_injured)

            injury_score = team_injury_rating - opponent_injury_rating
        except Exception as e:
            print(f"Error processing GAME_ID {game_id}: {e}")
            injury_score = None

        injury_scores.append(injury_score)

        time.sleep(0.5)
        print(f"Successfully parsed {game_id}")

    df['INJURY_SCORE'] = injury_scores
    return df

# %%
df = calculate_injury_score_sequential(df, player_ratings, find_injured_players, team_id)
# Out:
# Successfully parsed 0011800005
# Successfully parsed 0011800039
# Successfully parsed 0011800054
# Successfully parsed 0011800065
# Successfully parsed 0011800079
# Successfully parsed 0021800002
# Successfully parsed 0021800024
# Successfully parsed 0021800038
# Successfully parsed 0021800047
# Successfully parsed 0021800062
# Successfully parsed 0021800068
# Successfully parsed 0021800083
# Successfully parsed 0021800091
# Successfully parsed 0021800108
# Successfully parsed 0021800124
# Successfully parsed 0021800147
# Successfully parsed 0021800166
# Successfully parsed 0021800182
# Successfully parsed 0021800198
# Successfully parsed 0021800201
# Successfully parsed 0021800213
# Successfully parsed 0021800232
# Successfully parsed 0021800238
# Successfully parsed 0021800264
# Successfully parsed 0021800277
# Successfully parsed 0021800285
# Successfully parsed 0021800300
# Successfully parsed 0021800316
# Successfully parsed 0021800331
# Successfully parsed 0021800344
# Successfully parsed 0021800355
# Successfully parsed 0021800377
# Successfully parsed 0021800400
# Successfully parsed 0021800415
# Successfully parsed 0021800428
# Successfully parsed 0021800449
# Successfully parsed 0021800464
# Successfully parsed 0021800484
# Successfully parsed 0021800494
# Successfully parsed 0021800500
# Successfully parsed 0021800516
# Successfully parsed 0021800534
# Successfully parsed 0021800548
# Successfully parsed 0021800565
# Successfully parsed 0021800583
# Successfully parsed 0021800605
# Successfully parsed 0021800629
# Successfully parsed 0021800642
# Successfully parsed 0021800655
# Successfully parsed 0021800663
# Successfully parsed 0021800676
# Successfully parsed 0021800701
# Successfully parsed 0021800716
# Successfully parsed 0021800732
# Successfully parsed 0021800745
# Successfully parsed 0021800768
# Successfully parsed 0021800782
# Successfully parsed 0021800810
# Successfully parsed 0021800822
# Successfully parsed 0021800838
# Successfully parsed 0021800852
# Successfully parsed 0021800862
# Successfully parsed 0021800871
# Successfully parsed 0021800892
# Successfully parsed 0021800897
# Successfully parsed 0021800915
# Successfully parsed 0021800923
# Successfully parsed 0021800938
# Successfully parsed 0021800964
# Successfully parsed 0021800984
# Successfully parsed 0021801000
# Successfully parsed 0022000092
# Successfully parsed 0022000101
# Successfully parsed 0022000116
# Successfully parsed 0022000130
# Successfully parsed 0022000148
# Successfully parsed 0022000163
# Successfully parsed 0022000177
# Successfully parsed 0022000212
# Successfully parsed 0022000223
# Successfully parsed 0022000228
# Successfully parsed 0022000242
# Successfully parsed 0022000266
# Successfully parsed 0022000283
# Successfully parsed 0022000286
# Successfully parsed 0022000305
# Successfully parsed 0022000326
# Successfully parsed 0022000339
# Successfully parsed 0022000360
# Successfully parsed 0022000371
# Successfully parsed 0022000378
# Successfully parsed 0022000393
# Successfully parsed 0022000409
# Successfully parsed 0022000424
# Successfully parsed 0022000443
# Successfully parsed 0022000449
# Successfully parsed 0022000459
# Successfully parsed 0022000483
# Successfully parsed 0022000489
# Successfully parsed 0022000511
# Successfully parsed 0022000527
# Successfully parsed 0022000550
# Successfully parsed 0022000185
# Successfully parsed 0022000576
# Successfully parsed 0022000594
# Successfully parsed 0022000608
# Successfully parsed 0022000622
# Successfully parsed 0022000636
# Successfully parsed 0022000642
# Successfully parsed 0022000665
# Successfully parsed 0022000682
# Successfully parsed 0022000692
# Successfully parsed 0022000716
# Successfully parsed 0022000733
# Successfully parsed 0022000737
# Successfully parsed 0022000759
# Successfully parsed 0022000774
# Successfully parsed 0022000798
# Successfully parsed 0022000802
# Successfully parsed 0022000821
# Successfully parsed 0022000836
# Successfully parsed 0022000841
# Successfully parsed 0022000858
# Successfully parsed 0022000870
# Successfully parsed 0022000885
# Successfully parsed 0022000903
# Successfully parsed 0022000915
# Successfully parsed 0022000932
# Successfully parsed 0022000946
# Successfully parsed 0022000958
# Successfully parsed 0022000977
# Successfully parsed 0022000987
# Successfully parsed 0022001001
# Successfully parsed 0022001017
# Successfully parsed 0022001030
# Successfully parsed 0022001039
# Successfully parsed 0022001059
# Successfully parsed 0022001070
# Successfully parsed 0052000121
# Successfully parsed 0052000211
# Successfully parsed 0012100008
# Successfully parsed 0012100019
# Successfully parsed 0012100031
# Successfully parsed 0012100047
# Successfully parsed 0012100066
# Successfully parsed 0022100002
# Successfully parsed 0022100016
# Successfully parsed 0022100039
# Successfully parsed 0022100051
# Successfully parsed 0022100070
# Successfully parsed 0022100086
# Successfully parsed 0022100117
# Successfully parsed 0022100130
# Successfully parsed 0022100145
# Successfully parsed 0022100152
# Successfully parsed 0022100169
# Successfully parsed 0022100183
# Successfully parsed 0022100194
# Successfully parsed 0022100210
# Successfully parsed 0022100224
# Successfully parsed 0022100231
# Successfully parsed 0022100252
# Successfully parsed 0022100278
# Successfully parsed 0022100290
# Successfully parsed 0022100300
# Successfully parsed 0022100316
# Successfully parsed 0022100340
# Successfully parsed 0022100346
# Successfully parsed 0022100361
# Successfully parsed 0022100376
# Successfully parsed 0022100396
# Successfully parsed 0022100405
# Successfully parsed 0022100414
# Successfully parsed 0022100435
# Successfully parsed 0022100443
# Successfully parsed 0022100462
# Successfully parsed 0022100485
# Successfully parsed 0022100490
# Successfully parsed 0022100514
# Successfully parsed 0022100544
# Successfully parsed 0022100559
# Successfully parsed 0022100572
# Successfully parsed 0022100580
# Successfully parsed 0022100604
# Successfully parsed 0022100614
# Successfully parsed 0022100627
# Successfully parsed 0022200726
# Successfully parsed 0022200740
# Successfully parsed 0022200759
# Successfully parsed 0022200774
# Successfully parsed 0022200783
# Successfully parsed 0022200800
# Successfully parsed 0022200814
# Successfully parsed 0022200830
# Successfully parsed 0022200853
# Successfully parsed 0022200866
# Successfully parsed 0022200871
# Successfully parsed 0022200893
# Successfully parsed 0022200901
# Successfully parsed 0022200916
# Successfully parsed 0022200931
# Successfully parsed 0022200945
# Successfully parsed 0022200953
# Successfully parsed 0022200964
# Successfully parsed 0022200982
# Successfully parsed 0022200996
# Successfully parsed 0022201012
# Successfully parsed 0022201025
# Successfully parsed 0022201041
# Successfully parsed 0022201048
# Successfully parsed 0022201061
# Successfully parsed 0022201074
# Successfully parsed 0022201086
# Successfully parsed 0022201103
# Successfully parsed 0022201121
# Successfully parsed 0022201135
# Successfully parsed 0022201158
# Successfully parsed 0022201175
# Successfully parsed 0022201187
# Successfully parsed 0022201211
# Successfully parsed 0022201230
# Successfully parsed 0042200161
# Successfully parsed 0042200162
# Successfully parsed 0042200163
# Successfully parsed 0042200164
# Successfully parsed 0042200165
# Successfully parsed 0042200166
# Successfully parsed 0042200167
# Successfully parsed 0042200231
# Successfully parsed 0042200232
# Successfully parsed 0042200233
# Successfully parsed 0042200234
# Successfully parsed 0042200235
# Successfully parsed 0042200236
# Successfully parsed 0012300003
# Successfully parsed 0012300034
# Successfully parsed 0012300043
# Successfully parsed 0012300059
# Successfully parsed 0012300073
# Successfully parsed 0022300062
# Successfully parsed 0022300087
# Successfully parsed 0022300096
# Successfully parsed 0022300108
# Successfully parsed 0022300126
# Successfully parsed 0022300005
# Successfully parsed 0022300142
# Successfully parsed 0022300145
# Successfully parsed 0022300169
# Successfully parsed 0022300176
# Successfully parsed 0022300186
# Successfully parsed 0022300025
# Successfully parsed 0022300201
# Successfully parsed 0022300207
# Successfully parsed 0022300224
# Successfully parsed 0022300236
# Successfully parsed 0022300051
# Successfully parsed 0022300060
# Successfully parsed 0022300273
# Successfully parsed 0022300280
# Successfully parsed 0022301214
# Successfully parsed 0022301222
# Successfully parsed 0022300308
# Successfully parsed 0022300325
# Successfully parsed 0022300339
# Successfully parsed 0022300348
# Successfully parsed 0022300362
# Successfully parsed 0022300386
# Successfully parsed 0022300399
# Successfully parsed 0022300402
# Successfully parsed 0022300426
# Successfully parsed 0022300444
# Successfully parsed 0022300463
# Successfully parsed 0022300478
# Successfully parsed 0022300490
# Successfully parsed 0022300504
# Successfully parsed 0022300525
# Successfully parsed 0022300536
# Successfully parsed 0022300545
# Successfully parsed 0022300560
# Successfully parsed 0022300626
# Successfully parsed 0022300632
# Successfully parsed 0022300650
# Successfully parsed 0022300673
# Successfully parsed 0022300693
# Successfully parsed 0022300699
# Successfully parsed 0022300717
# Successfully parsed 0022300727
# Successfully parsed 0022300733
# Successfully parsed 0022300757
# Successfully parsed 0022300769
# Successfully parsed 0022300789
# Successfully parsed 0022300576
# Successfully parsed 0022300802
# Successfully parsed 0022300811
# Successfully parsed 0022300824
# Successfully parsed 0022300834
# Successfully parsed 0022300852
# Successfully parsed 0022300860
# Successfully parsed 0022300872
# Successfully parsed 0022300899
# Successfully parsed 0022300907
# Successfully parsed 0022300921
# Successfully parsed 0022300936
# Successfully parsed 0022300952
# Successfully parsed 0022300973
# Successfully parsed 0022300988
# Successfully parsed 0022301001
# Successfully parsed 0022301016
# Successfully parsed 0022301031
# Successfully parsed 0022301044
# Successfully parsed 0022301049
# Successfully parsed 0022301062
# Successfully parsed 0022301085
# Successfully parsed 0022300589
# Successfully parsed 0022301113
# Successfully parsed 0022301097
# Successfully parsed 0022301142
# Successfully parsed 0022301155
# Successfully parsed 0022301169
# Successfully parsed 0022301182
# Successfully parsed 0022301198
# Successfully parsed 0052300131
# Successfully parsed 0012400004
# Successfully parsed 0012400023
# Successfully parsed 0012400033
# Successfully parsed 0012400044
# Successfully parsed 0012400056
# Successfully parsed 0012400074
# Successfully parsed 0022400072
# Successfully parsed 0022400084
# Successfully parsed 0022400101
# Successfully parsed 0022400116
# Successfully parsed 0022400126
# Successfully parsed 0022400144
# Successfully parsed 0022400155
# Successfully parsed 0022400172
# Successfully parsed 0022400188
# Successfully parsed 0022400207
# Successfully parsed 0022400007
# Successfully parsed 0022400019
# Successfully parsed 0022400251
# Successfully parsed 0022400258
# Successfully parsed 0022400032
# Successfully parsed 0022400269
# Successfully parsed 0022400284
# Successfully parsed 0022400299
# Successfully parsed 0022400303
# Successfully parsed 0022400058
# Successfully parsed 0022400332
# Successfully parsed 0022400338
# Successfully parsed 0022400355
# Successfully parsed 0022401204
# Successfully parsed 0022401228
# Successfully parsed 0022400366
# Successfully parsed 0022400383
# Successfully parsed 0022400403
# Successfully parsed 0022400408
# Successfully parsed 0022400426
# Successfully parsed 0022400431
# Successfully parsed 0022400446
# Successfully parsed 0022400467
# Successfully parsed 0022400485
# Successfully parsed 0022400492
# Successfully parsed 0022400508

# %%
print("Done")
# Out:
# Done

# %%
df
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0       12018  1610612744               GSW  Golden State Warriors
# 1       12018  1610612744               GSW  Golden State Warriors
# 2       12018  1610612744               GSW  Golden State Warriors
# 3       12018  1610612744               GSW  Golden State Warriors
# 4       12018  1610612744               GSW  Golden State Warriors
# ..        ...         ...               ...                    ...
# 590     22024  1610612744               GSW  Golden State Warriors
# 591     22024  1610612744               GSW  Golden State Warriors
# 592     22024  1610612744               GSW  Golden State Warriors
# 593     22024  1610612744               GSW  Golden State Warriors
# 594     22024  1610612744               GSW  Golden State Warriors
#
#         GAME_ID  GAME_DATE      MATCHUP  WL  MIN  PTS  ...  AST  STL  BLK  \
# 0    0011800005 2018-09-29  GSW vs. MIN   0  241  110  ...   33    9    8
# 1    0011800039 2018-10-05  GSW vs. SAC   1  241  122  ...   29    8    6
# 2    0011800054 2018-10-08  GSW vs. PHX   0  239  109  ...   26    5    6
# 3    0011800065 2018-10-10    GSW @ LAL   0  241  113  ...   23   11    3
# 4    0011800079 2018-10-12  GSW vs. LAL   0  241  105  ...   25    8    4
# ..          ...        ...          ...  ..  ...  ...  ...  ...  ...  ...
# 590  0022400446 2024-12-30  GSW vs. CLE   0  241   95  ...   20    5    8
# 591  0022400467 2025-01-02  GSW vs. PHI   1  242  139  ...   41    5    8
# 592  0022400485 2025-01-04  GSW vs. MEM   1  241  121  ...   32   13    5
# 593  0022400492 2025-01-05  GSW vs. SAC   0  240   99  ...   22   10    3
# 594  0022400508 2025-01-07  GSW vs. MIA   0  240   98  ...   28    9    6
#
#      TOV  PF  PLUS_MINUS   SEASON  DaysSinceLast  IS_HOME_GAME  INJURY_SCORE
# 0     17  23        -4.0  2018-19            0.0             1        -35.15
# 1     12  18        28.0  2018-19            6.0             1        -24.66
# 2     18  26        -8.0  2018-19            3.0             1       -124.33
# 3     25  38       -10.0  2018-19            2.0             0        -53.67
# 4     16  30       -18.0  2018-19            2.0             1        -72.58
# ..   ...  ..         ...      ...            ...           ...           ...
# 590   14  14       -18.0  2024-25            2.0             1         21.89
# 591   11  22        34.0  2024-25            3.0             1        -50.95
# 592   18  18         8.0  2024-25            2.0             1         -4.08
# 593   22  21       -30.0  2024-25            1.0             1          1.80
# 594   10  15       -16.0  2024-25            2.0             1         68.39
#
# [595 rows x 32 columns]

# %%
df.to_csv("Warriors_7_Seasons_Data.csv", index=False)

# %%
df
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0       12018  1610612744               GSW  Golden State Warriors
# 1       12018  1610612744               GSW  Golden State Warriors
# 2       12018  1610612744               GSW  Golden State Warriors
# 3       12018  1610612744               GSW  Golden State Warriors
# 4       12018  1610612744               GSW  Golden State Warriors
# ..        ...         ...               ...                    ...
# 590     22024  1610612744               GSW  Golden State Warriors
# 591     22024  1610612744               GSW  Golden State Warriors
# 592     22024  1610612744               GSW  Golden State Warriors
# 593     22024  1610612744               GSW  Golden State Warriors
# 594     22024  1610612744               GSW  Golden State Warriors
#
#         GAME_ID  GAME_DATE      MATCHUP  WL  MIN  PTS  ...  AST  STL  BLK  \
# 0    0011800005 2018-09-29  GSW vs. MIN   0  241  110  ...   33    9    8
# 1    0011800039 2018-10-05  GSW vs. SAC   1  241  122  ...   29    8    6
# 2    0011800054 2018-10-08  GSW vs. PHX   0  239  109  ...   26    5    6
# 3    0011800065 2018-10-10    GSW @ LAL   0  241  113  ...   23   11    3
# 4    0011800079 2018-10-12  GSW vs. LAL   0  241  105  ...   25    8    4
# ..          ...        ...          ...  ..  ...  ...  ...  ...  ...  ...
# 590  0022400446 2024-12-30  GSW vs. CLE   0  241   95  ...   20    5    8
# 591  0022400467 2025-01-02  GSW vs. PHI   1  242  139  ...   41    5    8
# 592  0022400485 2025-01-04  GSW vs. MEM   1  241  121  ...   32   13    5
# 593  0022400492 2025-01-05  GSW vs. SAC   0  240   99  ...   22   10    3
# 594  0022400508 2025-01-07  GSW vs. MIA   0  240   98  ...   28    9    6
#
#      TOV  PF  PLUS_MINUS   SEASON  DaysSinceLast  IS_HOME_GAME  INJURY_SCORE
# 0     17  23        -4.0  2018-19            0.0             1        -35.15
# 1     12  18        28.0  2018-19            6.0             1        -24.66
# 2     18  26        -8.0  2018-19            3.0             1       -124.33
# 3     25  38       -10.0  2018-19            2.0             0        -53.67
# 4     16  30       -18.0  2018-19            2.0             1        -72.58
# ..   ...  ..         ...      ...            ...           ...           ...
# 590   14  14       -18.0  2024-25            2.0             1         21.89
# 591   11  22        34.0  2024-25            3.0             1        -50.95
# 592   18  18         8.0  2024-25            2.0             1         -4.08
# 593   22  21       -30.0  2024-25            1.0             1          1.80
# 594   10  15       -16.0  2024-25            2.0             1         68.39
#
# [595 rows x 32 columns]
